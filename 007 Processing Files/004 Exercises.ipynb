# %% [markdown]
# ### Exercise 1
#
# What do we expect from the `readlines()` method when the stream is associated with an empty file?
#
# ### Exercise 2
#
# What is the following code intended to do?
#
# ```python
# for line in open("file", "rt"):
#     for char in line:
#         if char.lower() not in "aeiouy ":
#             print(char, end='')
# ```
#
# ### Exercise 3
#
# You're going to process a bitmap stored in a file named `image.png`, and you want to read its contents as a whole into a `bytearray` variable named `image`. Add a line to the following code to achieve this goal.
#
# ```python
# try:
#     stream = open("image.png", "rb")
#     image = bytearray(stream.read())  # Inserted line
#     stream.close()
# except IOError:
#     print("failed")
# else:
#     print("success")
# ```

# %% [markdown]
# ### LAB1
#
# **Estimated Time:** 30-60 minutes
#
# **Level of Difficulty:** Medium
#
# **Objectives:**
# - Enhancing the student's skills in file operations (reading).
# - Utilizing data collections for counting multiple data points.
#
# **Scenario:**
# A text file contains some text (nothing unusual), but we need to know how often each letter appears in the text. This analysis can be useful in cryptography, so we want to perform it with respect to the Latin alphabet.
#
# **Your Task:**
# Write a program that:
# 1. Asks the user for the input file's name.
# 2. Reads the file (if possible) and counts all the Latin letters (treating lower- and upper-case letters as equal).
# 3. Prints a simple histogram in alphabetical order (only non-zero counts should be presented).
#
# Create a test file for the code and check if your histogram contains valid results.
#
# Assuming that the test file contains just one line filled with:
#
# ```
# aBc
# ```
# `samplefile.txt`
#
# The expected output should look as follows:
#
# ```
# a -> 1
# b -> 1
# c -> 1
# ```
#
# **Tip:** A dictionary is an ideal data collection medium for storing the counts. The letters can be keys while the counters can be values.

# %% [markdown]
# ## LAB2
#
# ### Estimated Time
# 15-30 minutes
#
# ### Level of Difficulty
# Medium
#
# ### Prerequisites
# 4.3.1.15
#
# ### Objectives
# - Improve the student's skills in file operations (reading/writing)
# - Utilize lambdas to modify the sort order
#
# ### Scenario
# The previous code needs enhancement. It's functional, but it can be improved.
#
# Your task is to make some amendments to achieve the following results:
#
# - The output histogram will be sorted based on the characters' frequency, with the most frequent characters appearing first.
# - The histogram should be saved to a file with the same name as the input file but with the suffix '.hist' appended to the original name.
#
# Assuming the input file contains a single line with:
#
# ```
# cBabAa
# ```
#
# `samplefile.txt`
#
# The expected output should look like this:
#
# ```
# a -> 3
# b -> 2
# c -> 1
# ```
#
# **Tip:** Use a lambda function to change the sort order.

# %% [markdown]
# ### LAB3
#
# **Estimated Time:** 30-90 minutes
#
# **Level of Difficulty:** Medium
#
# **Objectives:**
# - Enhance the student's skills in file operations (reading)
# - Refine the student's abilities in defining and using custom exceptions and dictionaries
#
# **Scenario:**
# Prof. Jekyll conducts classes with students and regularly makes notes in a text file. Each line of the file contains three elements: the student's first name, the student's last name, and the number of points the student received during certain classes.
#
# The elements are separated by white spaces. Each student may appear multiple times in Prof. Jekyll's file.
#
# The file may look as follows:
#
# ```
# John    Smith    5
# Anna    Boleyn   4.5
# John    Smith    2
# Anna    Boleyn   11
# Andrew  Cox      1.5
# ```
# `samplefile.txt`
#
# **Your task is to write a program that:**
# 1. Asks the user for Prof. Jekyll's file name.
# 2. Reads the file contents and calculates the total points received by each student.
# 3. Prints a simple (but sorted) report, like this:
#
# ```
# Andrew Cox      1.5
# Anna Boleyn     15.5
# John Smith      7.0
# ```
#
# **Note:**
# - Your program must be fully protected against all possible failures: the file's non-existence, the file being empty, or any input data errors. Encountering any data error should cause immediate program termination, and the error should be presented to the user.
# - Implement and use your own exceptions hierarchy. We've provided the base structure below; the second exception should be raised when a bad line is detected, and the third when the source file exists but is empty.
#
# **Tip:** Use a dictionary to store the students' data.

# %%
class StudentsDataException(Exception):
    pass

class BadLine(StudentsDataException):
    # Write your code here.
    pass

class FileEmpty(StudentsDataException):
    # Write your code here.
    pass
