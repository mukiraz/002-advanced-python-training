# %% [markdown]
# # Exercise 1
#
# ## Objectives:
# - Enhance the student's skills in creating classes from scratch
# - Learn to define and use instance variables
# - Learn to define and use methods
#
# ## Scenario:
# We need a class that can count seconds. It may seem simple, but we have specific requirements.
#
# Read the requirements carefully as the class you create will be used for launching rockets on international missions to Mars. This is a significant responsibility, and we are relying on you!
#
# Your class will be named Timer. The constructor should accept three arguments representing hours (a value in the range [0..23] - military time), minutes (in the range [0..59]), and seconds (in the range [0..59]).
#
# The default value for all parameters is zero. There is no need to perform validation checks.
#
# The class should provide the following features:
# - Objects of the class should be "printable," meaning they can implicitly convert themselves into strings in the format "hh:mm:ss," with leading zeros added for values less than 10.
# - The class should have parameterless methods called next_second() and previous_second(), which increment or decrement the time stored in the objects by +1 or -1 second, respectively.
#
# ## Hints:
# - All object properties should be private.
# - Consider writing a separate function (not a method) to format the time string.
#
# Complete the template provided in the editor. Run your code and verify that the output matches ours.
#
# ## Expected Output:
# 23:59:59
# 00:00:00
# 23:59:59

# %%
class Timer:
    def __init__( ??? ):
        #
        # Write code here
        #

    def __str__(self):
        #
        # Write code here
        #

    def next_second(self):
        #
        # Write code here
        #

    def prev_second(self):
        #
        # Write code here
        #


timer = Timer(23, 59, 59)
print(timer)
timer.next_second()
print(timer)
timer.prev_second()
print(timer)

# %% [markdown]
# # Exercise 2
#
# ## Objectives:
# - Enhance the student's skills in creating classes from scratch
# - Learn to define and use instance variables
# - Learn to define and use methods
#
# ## Scenario:
# Your task is to implement a class called Weeker. Yes, you read that correctly – the name reflects that objects of this class will store and manipulate days of the week.
#
# The class constructor accepts one argument – a string representing the name of the day of the week. The only acceptable values are:
#
# Mon, Tue, Wed, Thu, Fri, Sat, Sun
#
# Passing a value outside this set to the constructor should raise the WeekDayError exception (define it yourself; don't worry, we'll discuss the nature of exceptions soon). The class should provide the following features:
#
# - Objects of the class should be "printable," meaning they can implicitly convert themselves into strings in the same form as the constructor arguments.
# - The class should have one-parameter methods called add_days(n) and subtract_days(n). Here, n is an integer that updates the day of the week stored in the object to reflect the change in date by the indicated number of days, either forward or backward.
# - All object properties should be private.
#
# Complete the template provided in the editor, run your code, and check if your output matches ours.
#
# ## Expected Output:
# Mon
# Tue
# Sun
# Sorry, I can't serve your request.

# %%
class WeekDayError(Exception):
    pass
	

class Weeker:
    #
    # Write code here.
    #

    def __init__(self, day):
        #
        # Write code here.
        #

    def __str__(self):
        #
        # Write code here.
        #

    def add_days(self, n):
        #
        # Write code here.
        #

    def subtract_days(self, n):
        #
        # Write code here.
        #


try:
    weekday = Weeker('Mon')
    print(weekday)
    weekday.add_days(15)
    print(weekday)
    weekday.subtract_days(23)
    print(weekday)
    weekday = Weeker('Monday')
except WeekDayError:
    print("Sorry, I can't serve your request.")

# %% [markdown]
# # Exercise 3
#
# ## Objectives:
# - Enhance the student's skills in creating classes from scratch
# - Learn to define and use instance variables
# - Learn to define and use methods
#
# ## Scenario:
# Let's explore a unique place – a plane with the Cartesian coordinate system (learn more here: [Cartesian coordinate system](https://en.wikipedia.org/wiki/Cartesian_coordinate_system)).
#
# Each point on the plane can be represented by a pair of coordinates, commonly called x and y. Your task is to write a Python class that stores these coordinates as float numbers. Additionally, the objects of this class should be able to calculate the distance between any two points on the plane.
#
# This task is straightforward if you use the hypot() function (available in the math module), which calculates the length of the hypotenuse of a right triangle (more details here: [Hypotenuse](https://en.wikipedia.org/wiki/Hypotenuse) and [Python Math Module](https://docs.python.org/3.7/library/math.html#trigonometric-functions)).
#
# Here’s the outline for the class:
#
# - The class is called Point.
# - The constructor accepts two arguments (x and y), both defaulting to zero.
# - All properties should be private.
# - The class includes two parameterless methods called getx() and gety(), which return the respective coordinates (stored privately, hence not directly accessible from outside the object).
# - The class provides a method called distance_from_xy(x, y), which calculates and returns the distance between the point stored inside the object and another point given as a pair of floats.
# - The class provides a method called distance_from_point(point), which calculates the distance (similar to the previous method), but the other point's location is given as another Point class object.
#
# Complete the template provided in the editor, run your code, and verify that your output matches ours.
#
# ## Expected Output:
# 1.4142135623730951
# 1.4142135623730951

# %%
import math


class Point:
    def __init__(self, x=0.0, y=0.0):
        #
        # Write code here
        #

    def getx(self):
        #
        # Write code here
        #

    def gety(self):
        #
        # Write code here
        #

    def distance_from_xy(self, x, y):
        #
        # Write code here
        #

    def distance_from_point(self, point):
        #
        # Write code here
        #


point1 = Point(0, 0)
point2 = Point(1, 1)
print(point1.distance_from_point(point2))
print(point2.distance_from_xy(2, 0))

# %% [markdown]
# # Exercise 4
#
# ## Objectives:
# - Enhance the student's skills in creating classes from scratch
# - Learn to use composition
#
# ## Scenario:
# We will now embed the Point class (see Lab 3.4.1.14) within another class. Additionally, we will group three points into one class to define a triangle. How can we achieve this?
#
# The new class will be called Triangle, and here are our expectations:
#
# - The constructor accepts three arguments, all of which are objects of the Point class.
# - The points are stored inside the object as a private list.
# - The class provides a parameterless method called perimeter(), which calculates the perimeter of the triangle formed by the three points. The perimeter is the sum of all the sides' lengths (we mention this for completeness, even though we are sure you already know it well).
#
# Complete the template provided in the editor. Run your code and verify if the evaluated perimeter matches ours.
#
# Below is the Point class code used in the previous lab:
#
# ```python
# class Point:
#     def __init__(self, x=0.0, y=0.0):
#         self.__x = x
#         self.__y = y
# ```
#
# ## Expected Output:
# 3.414213562373095

# %%
import math


class Point:
    #
    # The code copied from the previous lab.
    #


class Triangle:
    def __init__(self, vertice1, vertice2, vertice3):
        #
        # Write code here
        #

    def perimeter(self):
        #
        # Write code here
        #


triangle = Triangle(Point(0, 0), Point(1, 0), Point(0, 1))
print(triangle.perimeter())
